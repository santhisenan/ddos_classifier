# %%
import numpy as np
import pandas as pd

# %%
data_normal = pd.read_csv('normal.csv', nrows = 4000) #1935959
data_smurf = pd.read_csv('smurf.csv', nrows = 4000) #12590
data_http = pd.read_csv('http.csv', nrows = 4000) #4110
data_udp = pd.read_csv('udp.csv', nrows = 4000) #201344
data_siddos = pd.read_csv('siddos.csv', nrows = 4000)#6665

# %%
# data_balanced = data_normal
# data_balanced.append(data_smurf)
# data_balanced.append(data_http)
# data_balanced.append(data_udp)
# data_balanced.append(data_siddos)
frames = [data_normal, data_smurf, data_http, data_udp, data_siddos]
data_balanced = pd.concat(frames, ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-88cdb57bd1b0> in <module>
#       4 # data_balanced.append(data_udp)
#       5 # data_balanced.append(data_siddos)
# ----> 6 frames = [data_normal, data_smurf, data_http, data_udp, data_siddos]
#       7 data_balanced = pd.concat(frames, ignore_index = True)
#
# NameError: name 'data_normal' is not defined

# %%
data_balanced.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0  SRC_ADD  DES_ADD  PKT_ID  FROM_NODE  TO_NODE PKT_TYPE  \
# 0              0     3.00    24.30  389693         21       23      tcp
# 1              1    15.00    24.15  201196         23       24      tcp
# 2              3    24.90     9.00  443135         23       21      ack
# 3              4    24.80     8.00  157335         23       21      ack
# 4              5    24.10     1.00  219350         21        1      ack
# 5              6    24.13    13.00  480053         24       23      ack
# 6              7     2.10    24.22  599411         23       24      cbr
# 7              8    24.20     2.00  551227         24       23      ack
# 8              9     2.00    24.20  399941         21       23      tcp
# 9             11    24.11    11.00  356924         23       22      ack
# 10            12    24.50     5.00  349309         21        5      ack
# 11            13     6.10    24.26  629078         23       24      cbr
# ...

# %%
data_balanced.to_csv('balanced_dataset.csv')
